# %% [markdown]
# Sting data type alphanumereic data

# %%
coin = "btc"

# %% [markdown]
# String opreattions

# %%
print(coin.startswith("O"))
print(coin.isdigit())
print(coin.replace("r", "ate"))


# text.title()
# text.strip()
# /text.split()

# Checking Methods
# text.startswith()
# text.endswith()
# text.isdigit()
# text.isalpha()
# Out:
# False
# False
# btc

# %%
first_name = "joseph"
sur_name = "victor"


print(len(first_name))
# Out:
# 6

# %% [markdown]
# Collect 5 usernames from the user.
# Each username must:
#
# 1. Be longer than  4 characters.
# 2. Contain only letters and numbers (no spaces or special characters).
#
# 3. Not already exist in the list.
#
#
# If a username is invalid or duplicated, display an appropriate error message and ask the user to enter another username.
# Store all valid usernames in a list.
#
# After collecting 5 valid usernames:
#
# Print the complete list of usernames.
# Print the username that comes first alphabetically.
# Print the username that comes last alphabetically.
# Print the longest username.
# Print the shortest username.

# %%
username_list = []

#check if the characters in the user are not either alphabet or letters 

#list out all special chara

while len(username_list) < 5:
    user_name = input("Please input your username:")

    if len(user_name) < 4:
        print("Username must be greater than 4 characters")
    elif user_name.isalnum():
        print("username can only contain letter 24tgand number,")
    else:
        user_name in username_list
        print("username alraedy exist,")
        username_list.append
print(username_list)
print("first alphabetically", (min))
print("last alphabetically" ,(max))
print("longest username" , (max))
print("shortest username",(min))
# Out:
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
# username can only contain letterand number,
