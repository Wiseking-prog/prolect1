# %% [markdown]
# explain string

# %%
coin = "btc"

# %% [markdown]
# String opreattions

# %%
print(coin.startswith("O"))
print(coin.isdigit())
print(coin.replace("r", "ate"))


# text.title()
# text.strip()
# /text.split()

# Checking Methods
# text.startswith()
# text.endswith()
# text.isdigit()
# text.isalpha()
# Out:
# False
# False
# btc
