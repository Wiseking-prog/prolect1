# %% [markdown]
# ### Projects We are going to be building the following Projects
#
# * To-do app
# * Expense tracker
# * Quiz game
# * Weather dashboard
# * Password manager
# * Blog website
# * Chat application
# * Library management system
