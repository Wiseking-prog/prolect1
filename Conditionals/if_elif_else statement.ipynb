# %% [markdown]
# #### What are Conditonal Statements?
# Conditional statements in Python allow your program to make decisions and execute specific blocks of code based on whether a condition is True or False.

# %% [markdown]
# #### Why do wwe have Conditionals
#
# - They give machines the ability to make decisions
# - a code uses if/else statment to check password: IF the password is true the uer can login
# ELSE we will display an error message showing that the inputed password is wron

# %%
#In python we have it like this and notice the syntax

fruit = "banana"

#now we are going to check if the fruit is banana

if fruit == "banana":
    print("the furit is banana")

else:
    print(f"the fruit is {fruit}")

# %% [markdown]
# #### Try this out:
#
# You are going to write code that will determine if an incoming cargo container is Approved, Quarantined, Taxed, or Rejected based on international law
#
# #### The program will take four inputs;
# - weight (float) in kilograms
# - contents of the cargo("string") either of this four "electronics", "produce", "textiles" or "hazardous"
# - destination (string) eihter "domestic" or "international"
# - has_permit (boolean: True or False)
#
# #### The engine must evaluate the input using these exact
#
# Rules:
#
# Immediate Rejection: Any shipment of "hazardous" material that weighs over 5,000 kg is automatically Rejected, regardless of
# permits or destination.
#
# Quarantine Rule: All "produce" going "international" must be Quarantined unless it weighs under 500 kg and has_permit is True (in which case it is Approved).
#
# The Tech Tax: "electronics" going "international" are subject to a high-value screening. If they weigh over 1,000 kg, they are marked as Taxed. If they weigh 1,000 kg or less and do not have a permit (has_permit == False), they are also Taxed. Otherwise, they are Approved.
#
# Standard Clearance: For all other combinations (e.g., textiles, or domestic produce):If it weighs over 10,000 kg and has_permit is False, it is Rejected due to safety limits.Otherwise, it is Approved
